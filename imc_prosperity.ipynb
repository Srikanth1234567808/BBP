# %%
# !pip install filterpy
# Out:
# Collecting filterpy
#   Downloading filterpy-1.4.5.zip (177 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numpy in /home/chebolu_srikanth/anaconda3/envs/tf/lib/python3.12/site-packages (from filterpy) (1.26.4)
# Requirement already satisfied: scipy in /home/chebolu_srikanth/anaconda3/envs/tf/lib/python3.12/site-packages (from filterpy) (1.12.0)
# Requirement already satisfied: matplotlib in /home/chebolu_srikanth/anaconda3/envs/tf/lib/python3.12/site-packages (from filterpy) (3.9.1)
# Requirement already satisfied: contourpy>=1.0.1 in /home/chebolu_srikanth/anaconda3/envs/tf/lib/python3.12/site-packages (from matplotlib->filterpy) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /home/chebolu_srikanth/anaconda3/envs/tf/lib/python3.12/site-packages (from matplotlib->filterpy) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/chebolu_srikanth/anaconda3/envs/tf/lib/python3.12/site-packages (from matplotlib->filterpy) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/chebolu_srikanth/anaconda3/envs/tf/lib/python3.12/site-packages (from matplotlib->filterpy) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /home/chebolu_srikanth/anaconda3/envs/tf/lib/python3.12/site-packages (from matplotlib->filterpy) (24.1)
# Requirement already satisfied: pillow>=8 in /home/chebolu_srikanth/anaconda3/envs/tf/lib/python3.12/site-packages (from matplotlib->filterpy) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/chebolu_srikanth/anaconda3/envs/tf/lib/python3.12/site-packages (from matplotlib->filterpy) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /home/chebolu_srikanth/anaconda3/envs/tf/lib/python3.12/site-packages (from matplotlib->filterpy) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /home/chebolu_srikanth/anaconda3/envs/tf/lib/python3.12/site-packages (from python-dateutil>=2.7->matplotlib->filterpy) (1.16.0)
# Building wheels for collected packages: filterpy
#   Building wheel for filterpy (setup.py) ... done
#   Created wheel for filterpy: filename=filterpy-1.4.5-py3-none-any.whl size=110458 sha256=09476c7458a2de1403b74bf824cbb5925c6922b9737e2ea3bb7d97343bab5a43
#   Stored in directory: /home/chebolu_srikanth/.cache/pip/wheels/77/bf/4c/b0c3f4798a0166668752312a67118b27a3cd341e13ac0ae6ee
# Successfully built filterpy
# Installing collected packages: filterpy
# Successfully installed filterpy-1.4.5

# %%
import numpy as np
import pandas as pd
import pywt
import yfinance as yf
import matplotlib.pyplot as plt

from filterpy.kalman import UnscentedKalmanFilter as UKF
from filterpy.kalman import MerweScaledSigmaPoints

from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.callbacks import EarlyStopping

ticker = '^NSEI'
start_date = '2007-09-17'
end_date = '2025-01-01'
data = yf.download(ticker, start=start_date, end=end_date)
data.sort_index(inplace=True)
data.reset_index(inplace=True)
df = data[['Date', 'Close']]

def fx(x, dt):
    return x

def hx(x): 
    return x

closing_prices = df['Close'].values
points = MerweScaledSigmaPoints(n=1, alpha=0.1, beta=2., kappa=0)
ukf = UKF(dim_x=1, dim_z=1, fx=fx, hx=hx, dt=1.0, points=points)
ukf.x = np.array([closing_prices[0]]) 
ukf.P *= 1.0
ukf.R *= 0.01  
ukf.Q *= 1e-5 

smoothed_prices = []
for z in closing_prices:
    ukf.predict()
    ukf.update(np.array([z]))
    smoothed_prices.append(ukf.x[0])

smoothed_prices = np.array(smoothed_prices)

scaler = MinMaxScaler(feature_range=(0, 1))
normalized_prices = scaler.fit_transform(smoothed_prices.reshape(-1, 1)).flatten()

def compute_wavelet_features(window, wavelet='haar', level=2):
    coeffs = pywt.wavedec(window, wavelet, level=level)
    return np.concatenate(coeffs)

window_size = 32
X, y = [], []

for i in range(len(normalized_prices) - window_size):
    window = normalized_prices[i:i + window_size]
    features = compute_wavelet_features(window)
    X.append(features)
    y.append(normalized_prices[i + window_size])

X = np.array(X)
y = np.array(y)

print("Feature matrix shape:", X.shape)
print("Target vector shape:", y.shape)

split_index = int(0.8 * len(X))
X_train, X_test = X[:split_index], X[split_index:]
y_train, y_test = y[:split_index], y[split_index:]

model = Sequential()
input_dim = X_train.shape[1]
model.add(Dense(64, input_dim=input_dim, activation='relu'))
model.add(Dense(32, activation='relu'))
model.add(Dense(1, activation='linear'))

model.compile(optimizer='adam', loss='mean_squared_error')
early_stop = EarlyStopping(monitor='loss', patience=10, restore_best_weights=True)

history = model.fit(X_train, y_train, epochs=100, batch_size=32, verbose=1, callbacks=[early_stop])

test_loss = model.evaluate(X_test, y_test, verbose=0)
print("Test MSE (normalized scale):", test_loss)

y_test_pred = model.predict(X_test).flatten()
y_test_inv = scaler.inverse_transform(y_test.reshape(-1, 1)).flatten()
y_pred_inv = scaler.inverse_transform(y_test_pred.reshape(-1, 1)).flatten()

test_dates = df['Date'][window_size + split_index: window_size + split_index + len(y_test_inv)]

plt.figure(figsize=(12, 6))
plt.plot(test_dates, y_test_inv, label='Actual Closing Price', marker='o')
plt.plot(test_dates, y_pred_inv, label='Predicted Closing Price', marker='x')
plt.xlabel("Date")
plt.ylabel("Closing Price")
plt.title(f"Next-Day Closing Price Prediction for {ticker}")
plt.legend()
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

future_predictions = []
last_window = normalized_prices[-window_size:].tolist()

for _ in range(14):
    features = compute_wavelet_features(np.array(last_window))
    features = features.reshape(1, -1)
    next_pred = model.predict(features)[0, 0]
    future_predictions.append(next_pred)
    last_window.append(next_pred)
    last_window = last_window[1:]

future_predictions_inv = scaler.inverse_transform(np.array(future_predictions).reshape(-1, 1)).flatten()
last_date = df['Date'].iloc[-1]
future_dates = pd.date_range(start=last_date + pd.Timedelta(days=1), periods=14, freq='B')

plt.figure(figsize=(12, 6))
plt.plot(future_dates, future_predictions_inv, label='Predicted Future Closing Prices', marker='x')
plt.xlabel("Date")
plt.ylabel("Predicted Close")
plt.title(f"14-Day Closing Price Forecast for {ticker}")
plt.xticks(rotation=45)
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()

print("Predicted closing prices for the next 14 days:")
for date, price in zip(future_dates, future_predictions_inv):
    print(f"{date.date()} --> {price:.2f}")
# Out:
# 2025-04-16 18:04:43.791716: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-04-16 18:04:43.813000: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-04-16 18:04:43.819018: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-04-16 18:04:43.836251: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-04-16 18:04:45.563022: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# YF.download() has changed argument auto_adjust default to True
# [*********************100%***********************]  1 of 1 completed
# Feature matrix shape: (4206, 32)
# Target vector shape: (4206,)
# Epoch 1/100
# /home/chebolu_srikanth/anaconda3/envs/tf/lib/python3.12/site-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1744806889.229579   43960 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2025-04-16 18:04:49.418819: W tensorflow/core/common_runtime/gpu/gpu_device.cc:2343] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0211
# Epoch 2/100
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.6108e-05
# Epoch 3/100
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 6.6880e-06
# Epoch 4/100
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.2661e-06
# Epoch 5/100
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.4733e-06
# Epoch 6/100
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.7682e-06
# Epoch 7/100
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.7911e-06
# Epoch 8/100
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.6985e-06
# Epoch 9/100
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.0490e-06
# Epoch 10/100
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 8.3590e-07
# Epoch 11/100
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 7.7513e-07
# Epoch 12/100
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.9887e-07
# Epoch 13/100
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 5.8812e-07
# Epoch 14/100
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.8730e-07
# Epoch 15/100
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.1946e-07
# Epoch 16/100
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.8183e-07
# Epoch 17/100
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.6332e-07
# Epoch 18/100
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.2946e-07
# Epoch 19/100
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.8674e-07
# Epoch 20/100
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.0994e-07
# Epoch 21/100
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.9413e-07
# Epoch 22/100
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.8471e-07
# Epoch 23/100
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 9.8022e-08
# Epoch 24/100
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.2258e-07
# Epoch 25/100
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.0977e-07
# Epoch 26/100
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.2188e-07
# Epoch 27/100
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.4412e-07
# Epoch 28/100
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.4112e-07
# Epoch 29/100
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.8513e-07
# Epoch 30/100
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 9.6060e-08
# Epoch 31/100
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.2490e-07
# Epoch 32/100
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.0905e-07
# Epoch 33/100
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.9489e-07
# Epoch 34/100
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.0530e-07
# Epoch 35/100
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.2742e-07
# Epoch 36/100
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.4705e-07
# Epoch 37/100
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.4010e-07
# Epoch 38/100
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.7575e-07
# Epoch 39/100
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.0767e-07
# Epoch 40/100
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.5217e-07
# Epoch 41/100
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6.4345e-07
# Epoch 42/100
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.8746e-07
# Epoch 43/100
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.3877e-06
# Epoch 44/100
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.4077e-06
# Test MSE (normalized scale): 1.0998189736710628e-06
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Predicted closing prices for the next 14 days:
# 2025-01-01 --> 24255.93
# 2025-01-02 --> 24219.87
# 2025-01-03 --> 24179.85
# 2025-01-06 --> 24133.71
# 2025-01-07 --> 24089.68
# 2025-01-08 --> 24039.40
# 2025-01-09 --> 23984.01
# 2025-01-10 --> 23923.26
# 2025-01-13 --> 23856.03
# 2025-01-14 --> 23783.96
# 2025-01-15 --> 23706.97
# 2025-01-16 --> 23623.32
# 2025-01-17 --> 23536.25
# 2025-01-20 --> 23442.92

# %%
import numpy as np
import pandas as pd
import pywt
import yfinance as yf
import matplotlib.pyplot as plt

from filterpy.kalman import UnscentedKalmanFilter as UKF
from filterpy.kalman import MerweScaledSigmaPoints

from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
from tensorflow.keras.callbacks import EarlyStopping

ticker = 'RELIANCE.NS'
start_date = '1996-01-01'
end_date = '2023-10-27'
data = yf.download(ticker, start=start_date, end=end_date)
data.sort_index(inplace=True)
data.reset_index(inplace=True)
df = data[['Date', 'Close']]

def fx(x, dt): 
    return x

def hx(x): 
    return x

closing_prices = df['Close'].values
points = MerweScaledSigmaPoints(n=1, alpha=0.1, beta=2., kappa=0)
ukf = UKF(dim_x=1, dim_z=1, fx=fx, hx=hx, dt=1.0, points=points)
ukf.x = np.array([closing_prices[0]])
ukf.P *= 1.0
ukf.R *= 0.01 
ukf.Q *= 1e-5 

smoothed_prices = []
for z in closing_prices:
    ukf.predict()
    ukf.update(np.array([z]))
    smoothed_prices.append(ukf.x[0])

smoothed_prices = np.array(smoothed_prices)

scaler = MinMaxScaler(feature_range=(0, 1))
normalized_prices = scaler.fit_transform(smoothed_prices.reshape(-1, 1)).flatten()

def compute_wavelet_features(window, wavelet='haar', level=2):
    coeffs = pywt.wavedec(window, wavelet, level=level)
    return np.concatenate(coeffs)

window_size = 32
X, y = [], []

for i in range(len(normalized_prices) - window_size):
    window = normalized_prices[i:i + window_size]
    features = compute_wavelet_features(window)
    X.append(features)
    y.append(normalized_prices[i + window_size])

X = np.array(X)
y = np.array(y)

print("Feature matrix shape:", X.shape)
print("Target vector shape:", y.shape)

split_index = int(0.8 * len(X))
X_train, X_test = X[:split_index], X[split_index:]
y_train, y_test = y[:split_index], y[split_index:]

X_train = X_train.reshape((X_train.shape[0], 1, X_train.shape[1]))
X_test = X_test.reshape((X_test.shape[0], 1, X_test.shape[1]))

model = Sequential()
model.add(LSTM(64, input_shape=(X_train.shape[1], X_train.shape[2]), return_sequences=False))
model.add(Dropout(0.2))
model.add(Dense(32, activation='relu'))
model.add(Dense(1))

model.compile(optimizer='adam', loss='mean_squared_error')
early_stop = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

history = model.fit(
    X_train, y_train,
    epochs=100,
    batch_size=32,
    validation_split=0.1,
    callbacks=[early_stop],
    verbose=1
)

y_test_pred = model.predict(X_test).flatten()
test_loss = model.evaluate(X_test, y_test, verbose=0)
print("Test MSE (normalized scale):", test_loss)

y_test_inv = scaler.inverse_transform(y_test.reshape(-1, 1)).flatten()
y_pred_inv = scaler.inverse_transform(y_test_pred.reshape(-1, 1)).flatten()

test_dates = df['Date'][window_size + split_index: window_size + split_index + len(y_test_inv)]

plt.figure(figsize=(12, 6))
plt.plot(test_dates, y_test_inv, label='Actual Closing Price', marker='o')
plt.plot(test_dates, y_pred_inv, label='Predicted Closing Price', marker='x')
plt.xlabel("Date")
plt.ylabel("Closing Price")
plt.title(f"Next-Day Closing Price Prediction for {ticker}")
plt.legend()
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

future_predictions = []
last_window = normalized_prices[-window_size:].tolist()

for _ in range(14):
    features = compute_wavelet_features(np.array(last_window))
    features = features.reshape(1, 1, -1) 
    next_pred = model.predict(features)[0, 0]
    future_predictions.append(next_pred)
    last_window.append(next_pred)
    last_window = last_window[1:]

future_predictions_inv = scaler.inverse_transform(np.array(future_predictions).reshape(-1, 1)).flatten()
last_date = df['Date'].iloc[-1]
future_dates = pd.date_range(start=last_date + pd.Timedelta(days=1), periods=14, freq='B')

plt.figure(figsize=(12, 6))
plt.plot(future_dates, future_predictions_inv, label='Predicted Future Closing Prices', marker='x')
plt.xlabel("Date")
plt.ylabel("Predicted Close")
plt.title(f"14-Day Closing Price Forecast for {ticker}")
plt.xticks(rotation=45)
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()

print("Predicted closing prices for the next 14 days:")
for date, price in zip(future_dates, future_predictions_inv):
    print(f"{date.date()} --> {price:.2f}")
# Out:
# [*********************100%***********************]  1 of 1 completed
# Feature matrix shape: (6960, 32)
# Target vector shape: (6960,)
# /home/chebolu_srikanth/anaconda3/envs/tf/lib/python3.12/site-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - loss: 0.0039 - val_loss: 1.4955e-04
# Epoch 2/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 9.9906e-05 - val_loss: 1.3266e-04
# Epoch 3/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.1838e-05 - val_loss: 1.0701e-04
# Epoch 4/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.5848e-05 - val_loss: 7.6117e-05
# Epoch 5/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.7949e-05 - val_loss: 6.3459e-05
# Epoch 6/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 4.1649e-05 - val_loss: 7.5192e-05
# Epoch 7/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.4617e-05 - val_loss: 3.9005e-05
# Epoch 8/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.1684e-05 - val_loss: 2.8365e-05
# Epoch 9/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.8421e-05 - val_loss: 1.0336e-05
# Epoch 10/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.9780e-05 - val_loss: 4.5827e-06
# Epoch 11/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.8537e-05 - val_loss: 4.7251e-06
# Epoch 12/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.6805e-05 - val_loss: 5.2506e-06
# Epoch 13/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.5130e-05 - val_loss: 1.4707e-05
# Epoch 14/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.3431e-05 - val_loss: 1.3410e-05
# Epoch 15/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 2.5624e-05 - val_loss: 1.3862e-05
# Epoch 16/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.9722e-05 - val_loss: 1.0057e-05
# Epoch 17/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.9281e-05 - val_loss: 1.4908e-05
# Epoch 18/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.6794e-05 - val_loss: 2.2473e-05
# Epoch 19/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.6655e-05 - val_loss: 1.3859e-05
# Epoch 20/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.5444e-05 - val_loss: 4.8640e-05
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# Test MSE (normalized scale): 0.01622316986322403
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# Predicted closing prices for the next 14 days:
# 2023-10-27 --> 1437.90
# 2023-10-30 --> 1629.66
# 2023-10-31 --> 1806.77
# 2023-11-01 --> 1943.76
# 2023-11-02 --> 1929.71
# 2023-11-03 --> 1998.27
# 2023-11-06 --> 2104.24
# 2023-11-07 --> 2247.23
# 2023-11-08 --> 2328.48
# 2023-11-09 --> 2403.32
# 2023-11-10 --> 2475.11
# 2023-11-13 --> 2562.86
# 2023-11-14 --> 2655.77
# 2023-11-15 --> 2750.22

# %%
import numpy as np
import pandas as pd
import pywt
import yfinance as yf
import matplotlib.pyplot as plt

from filterpy.kalman import UnscentedKalmanFilter as UKF
from filterpy.kalman import MerweScaledSigmaPoints

from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
from tensorflow.keras.callbacks import EarlyStopping

# =================== Load Data ===================
ticker = 'RELIANCE.NS'
start_date = '1996-01-01'
end_date = '2024-07-15'
data = yf.download(ticker, start=start_date, end=end_date)
data.sort_index(inplace=True)
data.reset_index(inplace=True)
df = data[['Date', 'Close']].copy()

# =================== Add Technical Indicators ===================
def add_technical_indicators(df):
    close = df['Close']
    # Simple Moving Averages
    df['SMA20'] = close.rolling(window=20).mean()
    df['SMA50'] = close.rolling(window=50).mean()
    # Exponential Moving Averages
    df['EMA12'] = close.ewm(span=12, adjust=False).mean()
    df['EMA26'] = close.ewm(span=26, adjust=False).mean()
    # MACD and Signal
    df['MACD'] = df['EMA12'] - df['EMA26']
    df['MACD_Signal'] = df['MACD'].ewm(span=9, adjust=False).mean()
    # RSI
    delta = close.diff()
    gain = delta.where(delta > 0, 0)
    loss = -delta.where(delta < 0, 0)
    avg_gain = gain.rolling(window=14).mean()
    avg_loss = loss.rolling(window=14).mean()
    rs = avg_gain / avg_loss
    df['RSI'] = 100 - (100 / (1 + rs))
    # Bollinger Bands
    window = 20
    df['BB_Middle'] = close.rolling(window=window).mean()
    df['BB_Std'] = close.rolling(window=window).std()
    df['BB_Upper'] = df['BB_Middle'] + (2 * df['BB_Std'])
    df['BB_Lower'] = df['BB_Middle'] - (2 * df['BB_Std'])
    df.drop('BB_Std', axis=1, inplace=True)
    return df

df = add_technical_indicators(df)
df.dropna(inplace=True)
df.reset_index(drop=True, inplace=True)

# =================== UKF Smoothing ===================
def fx(x, dt):
    return x

def hx(x):
    return x

closing_prices = df['Close'].values
points = MerweScaledSigmaPoints(n=1, alpha=0.1, beta=2., kappa=0)
ukf = UKF(dim_x=1, dim_z=1, fx=fx, hx=hx, dt=1.0, points=points)
ukf.x = np.array([closing_prices[0]])
ukf.P *= 1.0
ukf.R *= 0.01
ukf.Q *= 1e-5

smoothed_prices = []
for z in closing_prices:
    ukf.predict()
    ukf.update(np.array([z]))
    smoothed_prices.append(ukf.x[0])
smoothed_prices = np.array(smoothed_prices)
df['Smooth_Close'] = smoothed_prices

# =================== Normalize ===================
feature_columns = [
    'Smooth_Close', 'SMA20', 'SMA50', 'EMA12', 'EMA26',
    'MACD', 'MACD_Signal', 'RSI', 'BB_Middle', 'BB_Upper', 'BB_Lower'
]
scaler = MinMaxScaler(feature_range=(0, 1))
scaled_features = scaler.fit_transform(df[feature_columns])
close_scaler = MinMaxScaler(feature_range=(0, 1))
close_scaler.fit(df[['Smooth_Close']])

# =================== DWT Feature Extraction ===================
def compute_wavelet_features(window, wavelet='haar', level=2):
    coeffs = pywt.wavedec(window, wavelet, level=level)
    return np.concatenate(coeffs)

window_size = 32
X, y = [], []

for i in range(len(scaled_features) - window_size):
    # Wavelet features from smoothed close
    window = scaled_features[i:i + window_size, 0]
    wavelet_features = compute_wavelet_features(window)
    # Technical indicators at prediction time
    indicators = scaled_features[i + window_size, 1:]  # shape: (10,)
    # Combine features
    features = np.concatenate([wavelet_features, indicators])
    X.append(features)
    y.append(scaled_features[i + window_size, 0])  # Target: normalized smoothed close

X = np.array(X)
y = np.array(y)

print("Feature matrix shape:", X.shape)
print("Target vector shape:", y.shape)

# =================== Train-Test Split (Reshape for LSTM) ===================
split_index = int(0.8 * len(X))
X_train, X_test = X[:split_index], X[split_index:]
y_train, y_test = y[:split_index], y[split_index:]

X_train = X_train.reshape((X_train.shape[0], 1, X_train.shape[1]))
X_test = X_test.reshape((X_test.shape[0], 1, X_test.shape[1]))

# =================== LSTM Model ===================
model = Sequential()
model.add(LSTM(64, input_shape=(X_train.shape[1], X_train.shape[2]), return_sequences=False))
model.add(Dropout(0.2))
model.add(Dense(32, activation='relu'))
model.add(Dense(1))

model.compile(optimizer='adam', loss='mean_squared_error')
early_stop = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

# =================== Training ===================
history = model.fit(
    X_train, y_train,
    epochs=100,
    batch_size=32,
    validation_split=0.1,
    callbacks=[early_stop],
    verbose=1
)

# =================== Evaluation ===================
y_test_pred = model.predict(X_test).flatten()
test_loss = model.evaluate(X_test, y_test, verbose=0)
print("Test MSE (normalized scale):", test_loss)

y_test_inv = close_scaler.inverse_transform(y_test.reshape(-1, 1)).flatten()
y_pred_inv = close_scaler.inverse_transform(y_test_pred.reshape(-1, 1)).flatten()

test_dates = df['Date'][window_size + split_index: window_size + split_index + len(y_test_inv)]

# =================== Plot Results ===================
plt.figure(figsize=(12, 6))
plt.plot(test_dates, y_test_inv, label='Actual Closing Price', marker='o')
plt.plot(test_dates, y_pred_inv, label='Predicted Closing Price', marker='x')
plt.xlabel("Date")
plt.ylabel("Closing Price")
plt.title(f"Next-Day Closing Price Prediction for {ticker}")
plt.legend()
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# =================== Predict Next 14 Days ===================
future_predictions = []
last_window = scaled_features[-window_size:, 0].tolist()
last_indicators = scaled_features[-1, 1:]

for _ in range(14):
    wavelet_features = compute_wavelet_features(np.array(last_window))
    features = np.concatenate([wavelet_features, last_indicators])
    features = features.reshape(1, 1, -1)
    next_pred = model.predict(features)[0, 0]
    future_predictions.append(next_pred)
    # Update window and indicators for next prediction
    last_window.append(next_pred)
    last_window = last_window[1:]
    # For a real scenario, you should also update the indicators for the next day (here we just reuse the last available)

future_predictions_inv = close_scaler.inverse_transform(np.array(future_predictions).reshape(-1, 1)).flatten()
last_date = df['Date'].iloc[-1]
future_dates = pd.date_range(start=last_date + pd.Timedelta(days=1), periods=14, freq='B')

plt.figure(figsize=(12, 6))
plt.plot(future_dates, future_predictions_inv, label='Predicted Future Closing Prices', marker='x')
plt.xlabel("Date")
plt.ylabel("Predicted Close")
plt.title(f"14-Day Closing Price Forecast for {ticker}")
plt.xticks(rotation=45)
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()

print("Predicted closing prices for the next 14 days:")
for date, price in zip(future_dates, future_predictions_inv):
    print(f"{date.date()} --> {price:.2f}")
# Out:
# [*********************100%***********************]  1 of 1 completed
# /tmp/ipykernel_43960/2491929810.py:50: PerformanceWarning: dropping on a non-lexsorted multi-index without a level parameter may impact performance.
#   df.drop('BB_Std', axis=1, inplace=True)
# Feature matrix shape: (7084, 42)
# Target vector shape: (7084,)
# Epoch 1/100
# /home/chebolu_srikanth/anaconda3/envs/tf/lib/python3.12/site-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 8.3249e-04 - val_loss: 7.5156e-05
# Epoch 2/100
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 8.7816e-05 - val_loss: 1.5979e-04
# Epoch 3/100
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 4.8655e-05 - val_loss: 1.3145e-04
# Epoch 4/100
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.5721e-05 - val_loss: 1.2136e-04
# Epoch 5/100
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.9287e-05 - val_loss: 9.2681e-06
# Epoch 6/100
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.5109e-05 - val_loss: 2.6215e-05
# Epoch 7/100
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.0562e-05 - val_loss: 6.5842e-06
# Epoch 8/100
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.6568e-05 - val_loss: 3.8369e-05
# Epoch 9/100
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.6283e-05 - val_loss: 9.8836e-06
# Epoch 10/100
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.2137e-05 - val_loss: 6.9747e-06
# Epoch 11/100
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.2427e-05 - val_loss: 2.4663e-05
# Epoch 12/100
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.1121e-05 - val_loss: 5.4425e-06
# Epoch 13/100
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 9.4485e-06 - val_loss: 2.0470e-05
# Epoch 14/100
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.0074e-05 - val_loss: 8.9463e-06
# Epoch 15/100
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 9.0730e-06 - val_loss: 9.2066e-06
# Epoch 16/100
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 7.6382e-06 - val_loss: 6.5801e-06
# Epoch 17/100
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 8.4865e-06 - val_loss: 2.6105e-06
# Epoch 18/100
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.7944e-06 - val_loss: 1.7072e-05
# Epoch 19/100
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.9683e-06 - val_loss: 1.9172e-05
# Epoch 20/100
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.1593e-06 - val_loss: 1.3584e-05
# Epoch 21/100
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.5603e-06 - val_loss: 1.5427e-05
# Epoch 22/100
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 6.1854e-06 - val_loss: 1.0346e-05
# Epoch 23/100
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.5915e-06 - val_loss: 5.8869e-06
# Epoch 24/100
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.5802e-06 - val_loss: 5.2327e-06
# Epoch 25/100
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.3514e-06 - val_loss: 1.6134e-06
# Epoch 26/100
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.6770e-06 - val_loss: 2.2415e-06
# Epoch 27/100
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.4799e-06 - val_loss: 2.2618e-06
# Epoch 28/100
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.8591e-06 - val_loss: 1.7633e-06
# Epoch 29/100
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.3712e-06 - val_loss: 9.6944e-06
# Epoch 30/100
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.9461e-06 - val_loss: 2.5538e-05
# Epoch 31/100
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.1151e-06 - val_loss: 2.0391e-06
# Epoch 32/100
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 4.6647e-06 - val_loss: 2.8659e-06
# Epoch 33/100
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.6210e-06 - val_loss: 3.1404e-06
# Epoch 34/100
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.2209e-06 - val_loss: 1.1920e-05
# Epoch 35/100
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.1433e-06 - val_loss: 9.0823e-06
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Test MSE (normalized scale): 8.411393355345353e-05
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# Predicted closing prices for the next 14 days:
# 2024-07-15 --> 1496.84
# 2024-07-16 --> 1499.90
# 2024-07-17 --> 1501.57
# 2024-07-18 --> 1501.92
# 2024-07-19 --> 1500.66
# 2024-07-22 --> 1501.37
# 2024-07-23 --> 1501.69
# 2024-07-24 --> 1501.97
# 2024-07-25 --> 1501.45
# 2024-07-26 --> 1501.38
# 2024-07-29 --> 1501.22
# 2024-07-30 --> 1500.81
# 2024-07-31 --> 1500.25
# 2024-08-01 --> 1500.63
